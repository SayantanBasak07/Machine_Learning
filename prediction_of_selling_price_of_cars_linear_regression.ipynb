# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('linear_regression.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
pwd
# Out:
# 'C:\\Users\\KIIT'

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 9841-2D5E
#
#  Directory of C:\Users\KIIT
#
# 05-11-2022  11:13    <DIR>          .
# 24-01-2022  21:56    <DIR>          ..
# 05-11-2022  11:14    <DIR>          .conda
# 16-08-2022  14:07                25 .condarc
# 16-08-2022  14:07    <DIR>          .continuum
# 05-11-2022  10:07    <DIR>          .ipynb_checkpoints
# 17-08-2022  10:20    <DIR>          .ipython
# 17-08-2022  10:15    <DIR>          .jupyter
# 30-10-2022  13:41    <DIR>          .matplotlib
# 15-07-2022  18:39    <DIR>          .ms-ad
# 24-11-2021  01:29    <DIR>          .nbi
# 30-10-2022  23:09    <DIR>          .spyder-py3
# 24-11-2021  01:54    <DIR>          .vscode
# 18-08-2022  16:00            14,863 09-Objects and Data Structures Assessment Test.ipynb
# 24-07-2022  00:42               466 2ndlargestnumber.c
# 24-07-2022  01:07            41,447 2ndlargestnumber.exe
# 23-11-2021  09:57    <DIR>          3D Objects
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()  #gives count of non null values in a column
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# non numeric :
#car_name,fuel type,seller type,transmission

# %%
print(df.Fuel_Type.value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df.replace({"Fuel_Type":{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
df.replace({"Seller_Type":{'Dealer':0,'Individual':1}},inplace=True)
df.replace({"Transmission":{'Manual':0,'Automatic':1}},inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner
# 0              0             0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    int64
#  6   Seller_Type    301 non-null    int64
#  7   Transmission   301 non-null    int64
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 21.3+ KB

# %%
#splitting
x=df.drop(["Car_Name","Selling_Price"],axis=1)
y=df["Selling_Price"]

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split  #library for splitting data for test and train

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_test
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 99   2010         20.450       50024          1            0             0
# 161  2014          0.826       23000          0            1             0
# 89   2014          6.760       40000          0            0             0
# 30   2012          5.980       51439          1            0             0
# 232  2015         14.790       12900          0            0             1
# ..    ...            ...         ...        ...          ...           ...
# 172  2014          0.640       13700          0            1             0
# 94   2008         22.780       89000          0            0             1
# 160  2011          0.950       24000          0            1             0
# 199  2007          0.580       53000          0            1             0
# 91   2014         16.090       58242          1            0             0
#
#      Owner
# 99       0
# 161      0
# 89       0
# 30       0
# ...

# %%
y_test
# Out:
# 99      9.65
# 161     0.45
# 89      4.75
# 30      3.10
# 232    11.45
#        ...
# 172     0.40
# 94      4.00
# 160     0.45
# 199     0.12
# 91     11.25
# Name: Selling_Price, Length: 61, dtype: float64

# %%
x_train
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 235  2017           9.40       15141          0            0             0
# 106  2014           3.45       16500          0            1             0
# 10   2017           3.60        2135          0            0             0
# 152  2012           0.99       13000          0            1             0
# 77   2004          12.35      135154          0            0             1
# ..    ...            ...         ...        ...          ...           ...
# 75   2015           6.80       36000          0            0             0
# 22   2011           8.01       50000          0            0             1
# 72   2013          18.61       56001          0            0             0
# 15   2016          10.79       43000          1            0             0
# 168  2013           0.73       12000          0            1             0
#
#      Owner
# 235      0
# 106      1
# 10       0
# 152      0
# ...

# %%
y_train
# Out:
# 235    9.10
# 106    1.35
# 10     2.85
# 152    0.50
# 77     1.50
#        ...
# 75     3.95
# 22     4.40
# 72     7.45
# 15     7.75
# 168    0.42
# Name: Selling_Price, Length: 240, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics  #for accuracy and error detection

# %%
#load the model
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred=lr.predict(x_train)
test_pred=lr.predict(x_test)

# %%
test_pred
# Out:
# array([10.39222503,  0.71269634,  4.26367425,  4.89542882,  9.84484784,
#         4.22631808,  7.1173891 ,  7.37327394,  0.1592961 ,  5.16712598,
#         6.20624893,  6.17414198,  2.11880837,  7.74045843,  1.92235986,
#         1.71406658,  2.02899942,  1.8536463 ,  9.35171759,  4.2546458 ,
#         1.48996098,  9.14496453,  1.45846216,  9.63402658,  0.82165042,
#         8.07898502,  1.53763892, -3.19873666,  4.22373915,  2.09526116,
#         3.42865389,  3.72427545,  5.58001877,  7.75879392, -1.91563192,
#         6.80980082,  8.20694812,  5.81047156,  6.15629896,  6.27493028,
#        16.02197751,  2.07455343,  1.04886513, -0.45830577,  6.82090538,
#         6.78567581,  0.98725428,  6.83257783, 14.31925066,  3.01359825,
#         8.04481951, -0.89441322,  8.99139759,  1.14814903,  2.1191082 ,
#        -0.82919712,  0.68456956, 10.02743111, -0.46773344, -2.43254957,
#        10.0831552 ])

# %%
#squared error
error_train=metrics.r2_score(y_train,train_pred)
error_train
# Out:
# 0.8838169193709794

# %%
error_test=metrics.r2_score(y_test,test_pred)
error_test
# Out:
# 0.8401532365377683

# %%
plt.scatter(train_pred,y_train)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
# Out:
# Text(0, 0.5, 'Predicted Price')

# %%
plt.scatter(test_pred,y_test)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
# Out:
# Text(0, 0.5, 'Predicted Price')
